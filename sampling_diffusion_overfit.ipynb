# %%
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from plotting_utils import *
import torch
import numpy as np

# %%
import guided_diffusion_v3 as gd

def create_gaussian_diffusion(
    *,
    steps=1000,
    learn_sigma=False,
    sigma_small=False,
    noise_schedule="linear",
    use_kl=False,
    predict_xstart=False,
    rescale_timesteps=False,
    rescale_learned_sigmas=False,
    timestep_respacing="",
):
    betas = gd.get_named_beta_schedule(noise_schedule, steps)
    if use_kl:
        loss_type = gd.LossType.RESCALED_KL
    elif rescale_learned_sigmas:
        loss_type = gd.LossType.RESCALED_MSE
    else:
        loss_type = gd.LossType.MSE
    if not timestep_respacing:
        timestep_respacing = [steps]
    return gd.SpacedDiffusion(
        use_timesteps=gd.space_timesteps(steps, timestep_respacing),
        betas=betas,
        model_mean_type=(
            gd.ModelMeanType.EPSILON if not predict_xstart else gd.ModelMeanType.START_X
        ),
        model_var_type=(
            (
                gd.ModelVarType.FIXED_LARGE
                if not sigma_small
                else gd.ModelVarType.FIXED_SMALL
            )
            if not learn_sigma
            else gd.ModelVarType.LEARNED_RANGE
        ),
        loss_type=loss_type,
        rescale_timesteps=rescale_timesteps,
    )

diffusion = create_gaussian_diffusion()

# %%
# input_folder = r'C:\Users\u_imagenes\Documents\smerino\testing\input'
# output_folder = r'C:\Users\u_imagenes\Documents\smerino\testing\target_enh'
input_folder = r'C:\Users\sebas\Documents\Data\DiffusionBeamformer\input_overfit'
output_folder = r'C:\Users\sebas\Documents\Data\DiffusionBeamformer\target_overfit'

data = gd.CustomDataset(input_folder, output_folder, transform=True)
device = torch.device("cuda:0" if torch.cuda.is_available() else torch.device('cpu'))

# %%
BATCH_SIZE = 1
dataloader = DataLoader(data, batch_size=BATCH_SIZE, shuffle=False, drop_last=True)
x_sample, y_sample = next(iter(dataloader))
x_sample = x_sample.to(device)
y_sample = y_sample.to(device)

# %%
from model7 import UNETv13

device = torch.device("cuda:0" if torch.cuda.is_available() else torch.device('cpu'))
save_dir = r'.\weights\v13A'
training_epochs = 10
model = UNETv13(residual=False, attention_res=[]).to(device)
model.load_state_dict(torch.load(f"{save_dir}\\model_{training_epochs}.pth", map_location=device))
print("Num params: ", sum(p.numel() for p in model.parameters()))
# Out:
# Num params:  32676097

# %%
plt.figure(figsize=(9,3))
loss_npy = np.load(f"{save_dir}\\loss_{training_epochs}.npy")
plt.scatter([x for x in range(len(loss_npy))],loss_npy, s=0.2)
plt.xlabel('# Iteration')
plt.ylabel('Loss')
#plt.xlim(000,35000)
#plt.ylim(0,0.8)
plt.show()

# %% [markdown]
# ## Sampling

# %%
y_gen = diffusion.p_sample_loop(model,y_sample.shape,x_sample, progress=True, clip_denoised=False)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 y_gen = diffusion.p_sample_loop(model,y_sample.shape,x_sample, progress=True, clip_denoised=False)
#
# File c:\Users\sebas\Documents\gitRepos\DiffusionBeamformer\guided_diffusion_v3.py:422, in GaussianDiffusion.p_sample_loop(self, model, shape, x, noise, clip_denoised, denoised_fn, model_kwargs, device, progress)
#     404 """
#     405 Generate samples from the model.
#     406
#    (...)
#     419 :return: a non-differentiable batch of samples.
#     420 """
#     421 final = None
# --> 422 for sample in self.p_sample_loop_progressive(
#     423     model,
#     424     shape,
#     425     x,
#     426     noise=noise,
#     427     clip_denoised=clip_denoised,
#     428     denoised_fn=denoised_fn,
#     429     model_kwargs=model_kwargs,
#     430     device=device,
#     431     progress=progress,
#     432 ):
#     433     final = sample
#     434 return final["sample"]
#
# File c:\Users\sebas\Documents\gitRepos\DiffusionBeamformer\guided_diffusion_v3.py:474, in GaussianDiffusion.p_sample_loop_progressive(self, model, shape, x, noise, clip_denoised, denoised_fn, model_kwargs, device, progress)
#     472 t = th.tensor([i] * shape[0], device=device)
#     473 with th.no_grad():
# --> 474     out = self.p_sample(
#     475         model,
#     476         x,
#     477         img,
#     478         t,
#     479         clip_denoised=clip_denoised,
#     480         denoised_fn=denoised_fn,
#     481         model_kwargs=model_kwargs,
#     482     )
#     483     yield out
#     484     img = out["sample"]
#
# File c:\Users\sebas\Documents\gitRepos\DiffusionBeamformer\guided_diffusion_v3.py:376, in GaussianDiffusion.p_sample(self, model, x, y, t, clip_denoised, denoised_fn, model_kwargs)
#     357 def p_sample(
#     358     self, model, x, y, t, clip_denoised=True, denoised_fn=None, model_kwargs=None
#     359 ):
#     360     """
#     361     Sample y_{t-1} from the model at the given timestep.
#     362
#    (...)
#     374              - 'pred_xstart': a prediction of y_0.
#     375     """
# --> 376     out = self.p_mean_variance(
#     377         model,
#     378         x,
#     379         y,
#     380         t,
#     381         clip_denoised=clip_denoised,
#     382         denoised_fn=denoised_fn,
#     383         model_kwargs=model_kwargs,
#     384     )
#     385     noise = th.randn_like(y)
#     386     nonzero_mask = (
#     387         (t != 0).float().view(-1, *([1] * (len(y.shape) - 1)))
#     388     )  # no noise when t == 0
#
# File c:\Users\sebas\Documents\gitRepos\DiffusionBeamformer\guided_diffusion_v3.py:946, in SpacedDiffusion.p_mean_variance(self, model, *args, **kwargs)
#     943 def p_mean_variance(
#     944     self, model, *args, **kwargs
#     945 ):  # pylint: disable=signature-differs
# --> 946     return super().p_mean_variance(self._wrap_model(model), *args, **kwargs)
#
# File c:\Users\sebas\Documents\gitRepos\DiffusionBeamformer\guided_diffusion_v3.py:261, in GaussianDiffusion.p_mean_variance(self, model, x, y, t, clip_denoised, denoised_fn, model_kwargs)
#     259 B, C = y.shape[:2]
#     260 assert t.shape == (B,)
# --> 261 model_output = model(x, y, self._scale_timesteps(t), **model_kwargs)
#     263 if self.model_var_type in [ModelVarType.LEARNED, ModelVarType.LEARNED_RANGE]:
#     264     assert model_output.shape == (B, C * 2, *y.shape[2:])
#
# File c:\Users\sebas\Documents\gitRepos\DiffusionBeamformer\guided_diffusion_v3.py:977, in _WrappedModel.__call__(self, x, y, ts, **kwargs)
#     975 if self.rescale_timesteps:
#     976     new_ts = new_ts.float() * (1000.0 / self.original_num_steps)
# --> 977 return self.model(x, y, new_ts, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\sebas\Documents\gitRepos\DiffusionBeamformer\model7.py:108, in UNETv13.forward(self, x, y, t)
#     106     skip_connections.append(x)
#     107     x = self.pool(x)
# --> 108     x = self.downBlocks[idx](x, time_emb)
#     109     x = self.downAttention[idx](x)
#     111 # Convolutional layers and up-sampling
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\sebas\Documents\gitRepos\DiffusionBeamformer\model7.py:213, in ResBlock.forward(self, x, emb)
#     205 def forward(self, x, emb):
#     206     """
#     207     Apply the block to a Tensor, conditioned on a timestep embedding.
#     208
#    (...)
#     211     :return: an [N x C x ...] Tensor of outputs.
#     212     """
# --> 213     return checkpoint(
#     214         self._forward, (x, emb), self.parameters(), self.use_checkpoint
#     215     )
#
# File c:\Users\sebas\Documents\gitRepos\DiffusionBeamformer\nn.py:139, in checkpoint(func, inputs, params, flag)
#     137     return CheckpointFunction.apply(func, len(inputs), *args)
#     138 else:
# --> 139     return func(*inputs)
#
# File c:\Users\sebas\Documents\gitRepos\DiffusionBeamformer\model7.py:227, in ResBlock._forward(self, x, emb)
#     225     scale, shift = th.chunk(emb_out, 2, dim=1)
#     226     h = out_norm(h) * (1 + scale) + shift
# --> 227     h = out_rest(h)
#     228 else:
#     229     h = h + emb_out
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(9,3))
plt.subplot(1,2,1)
show_tensor_image(y_gen.cpu())
plt.colorbar()
plt.title('Diffusion')

plt.subplot(1,2,2)
show_tensor_image(y_sample.cpu())
plt.colorbar()
plt.title('Objective')
plt.show()

# %%
y_gen = diffusion.p_sample_loop(model,y_sample.shape,x_sample, progress=True, clip_denoised=True)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(9, 3))
plt.subplot(1, 2, 1)
show_tensor_image(y_gen.cpu())
plt.colorbar()
plt.title('Diffusion')

plt.subplot(1, 2, 2)
show_tensor_image(y_sample.cpu())
plt.colorbar()
plt.title('Objective')
plt.show()

# %%
intermediate = []
for step in diffusion.p_sample_loop_progressive(model,y_sample.shape,x_sample, progress=True, clip_denoised=True):
    intermediate.append(step['sample'].cpu().detach())
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
show_reverse_process(intermediate[::100])

plt.figure(figsize=(9, 3))
plt.subplot(1, 2, 1)
show_tensor_image(intermediate[-1])
plt.colorbar()
plt.title('Diffusion')

plt.subplot(1, 2, 2)
show_tensor_image(y_sample.cpu())
plt.colorbar()
plt.title('Objective')
plt.show()
